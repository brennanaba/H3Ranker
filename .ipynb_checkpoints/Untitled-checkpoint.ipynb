# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df  = pd.read_csv("nohup.out", delimiter=" ")
cols = df.columns

# %%
plt.figure(dpi = 300)
plt.plot(df[cols[1]])
plt.plot(df[cols[2]])
plt.legend(["Train", "Validate"])

# %%
np.argmin(df[cols[2]]), np.min(df[cols[2]])
# Out:
# (141, 1.9946983645156935)
